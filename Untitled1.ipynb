# %% [markdown]
# <a href="https://colab.research.google.com/github/Asylcreek/StartNG-Internship/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/gdrive/My Drive/ml-20m/ratings.csv')

# %%
df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
movie_titles = pd.read_csv('/content/gdrive/My Drive/ml-20m/movies.csv')
movie_titles.head()
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
# df.info()
# movie_titles.info()
df = pd.merge(df, movie_titles, on = 'movieId')

# %%
df
# Out:
#           userId  ...                                  genres
# 0              1  ...              Adventure|Children|Fantasy
# 1              5  ...              Adventure|Children|Fantasy
# 2             13  ...              Adventure|Children|Fantasy
# 3             29  ...              Adventure|Children|Fantasy
# 4             34  ...              Adventure|Children|Fantasy
# 5             54  ...              Adventure|Children|Fantasy
# 6             88  ...              Adventure|Children|Fantasy
# 7             91  ...              Adventure|Children|Fantasy
# 8            116  ...              Adventure|Children|Fantasy
# 9            119  ...              Adventure|Children|Fantasy
# 10           120  ...              Adventure|Children|Fantasy
# 11           124  ...              Adventure|Children|Fantasy
# 12           127  ...              Adventure|Children|Fantasy
# 13           128  ...              Adventure|Children|Fantasy
# ...

# %%
df.describe()
# Out:
#              userId       movieId        rating     timestamp
# count  2.000026e+07  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00  1.100918e+09
# std    4.003863e+04  1.978948e+04  1.051989e+00  1.621694e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    3.439500e+04  9.020000e+02  3.000000e+00  9.667977e+08
# 50%    6.914100e+04  2.167000e+03  3.500000e+00  1.103556e+09
# 75%    1.036370e+05  4.770000e+03  4.000000e+00  1.225642e+09
# max    1.384930e+05  1.312620e+05  5.000000e+00  1.427784e+09

# %%
Ratings = pd.DataFrame(df.groupby('title') ['rating'].mean())
Ratings.head()
# Out:
#                                                       rating
# title
# "Great Performances" Cats (1998)                    2.748387
# #chicagoGirl: The Social Network Takes on a Dic...  3.666667
# $ (Dollars) (1971)                                  2.833333
# $5 a Day (2008)                                     2.871795
# $9.99 (2008)                                        3.009091

# %%
Ratings['number_of_ratings'] = df.groupby('title')['rating'].count()
Ratings.head
# Out:
# <bound method NDFrame.head of                                                       rating  number_of_ratings
# title
# "Great Performances" Cats (1998)                    2.748387                155
# #chicagoGirl: The Social Network Takes on a Dic...  3.666667                  3
# $ (Dollars) (1971)                                  2.833333                 24
# $5 a Day (2008)                                     2.871795                 39
# $9.99 (2008)                                        3.009091                 55
# $ellebrity (Sellebrity) (2012)                      2.000000                  2
# '71 (2014)                                          3.657143                 35
# 'Hellboy': The Seeds of Creation (2004)             3.028736                 87
# 'Human' Factor, The (Human Factor, The) (1975)      2.250000                  2
# 'Neath the Arizona Skies (1934)                     2.318182                 22
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
Ratings['rating'].hist(bins=50)

# %%
Ratings['number_of_ratings'].hist(bins=60)

# %%
import seaborn as sns
sns.jointplot(x='rating', y='number_of_ratings', data=Ratings)

# %%
movie_matrix = df.pivot_table(index='userId', columns='title', values='rating')
movie_matrix.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-9f511be3afce> in <module>()
# ----> 1 movie_matrix = df.pivot_table(index='userId', columns='title', values='rating')
#       2 movie_matrix.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    5757                            aggfunc=aggfunc, fill_value=fill_value,
#    5758                            margins=margins, dropna=dropna,
# -> 5759                            margins_name=margins_name)
#    5760
#    5761     def stack(self, level=-1, dropna=True):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     107             else:
# ...
